# %%
# install all dependencies
# !pip install torch torchvision diffusers transformers accelerate Pillow tqdm bitsandbytes -q

# %%
# clone the Github repo
# !git clone https://github.com/AdelynnWu/cs4782-final-project.git
# %cd cs4782-final-project
# Out:
# Cloning into 'cs4782-final-project'...
# remote: Enumerating objects: 791, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 791 (delta 64), reused 140 (delta 40), pack-reused 620 (from 1)
# Receiving objects: 100% (791/791), 406.97 MiB | 19.78 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# Updating files: 100% (599/599), done.
# /content/cs4782-final-project

# %%
# generate class prior images
# change the class prompt to the class of the subject you want to generate
# !python code/generate_class_data.py \
    --class_prompt "<subject class>" \
    --num_images 200 \
    --output_dir data/class_images \
    --batch_size 10
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Generating 136 class images with prompt: 'a water bottle'
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json: 100% 541/541 [00:00<00:00, 3.43MB/s]
# ...
# Fetching 13 files: 100% 13/13 [00:48<00:00,  3.72s/it]
# Download complete: : 4.27GB [00:48, 109MB/s]
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]
# Loading pipeline components...:  17% 1/6 [00:01<00:07,  1.50s/it]
#
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
#
# ...

# %%
# generate some unique token identifiers to use
# !python /content/cs4782-final-project/code/token_utils.py
# Out:
# ...
# DreamBooth Rare Token Identifier Candidates
# ...
#
# These tokens have minimal semantic prior in the CLIP
# tokenizer, making them good unique identifiers for binding
# to a specific subject.
#
# ...
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 5.44MB/s]
# vocab.json: 961kB [00:00, 117MB/s]
# merges.txt: 525kB [00:00, 98.9MB/s]
# tokenizer.json: 2.22MB [00:00, 134MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.20MB/s]
#   Token ID  Token String
# ------------------------------
#       5001  tf
#       5014  .#
#       5025  tho
#       5028  bee
#       5039  tan
#       5051  gp
#       5054  lyn
#       5056  zo
#       5081  ->
#       5128  fam
#       5139  nba
#       5150  cho
#       5157  vy
#       5162  bio
#       5164  pin
#       5167  ))
#       5168  pot
#       5180  hh
#       5182  aid
#       5187  amy
#
# Recommended: Pick one and use it as `identifier_token` in config.py
# Default 'sks' (token 48136 in CLIP) is a commonly used choice.
#
# ...

# %%
# run train script to train the model on subject & class images
# replace <subject_img_folder> with the name of the folder containing your 3-5 subject images under /data
# replace <subject class> with the class of the subject being generated
# replace <identifier> with the unique identifier chosen to be binded to the subject
# replace <model_name> with the name of the model you want to save it as
# !python /content/cs4782-final-project/code/train.py \
  --subject_dir /content/cs4782-final-project/data/<subject_img_folder>\
  --class_dir /content/cs4782-final-project/data/class_images\
  --class_noun "<subject class>" \
  --identifier "<identifier>" \
  --output_dir /content/cs4782-final-project/results/<model_name>\
  --steps 800 \
  --lr 5e-6 \
  --unet_train_mode cross_attention\
  --no_prior_preservation
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# DreamBooth Training
# ...
#   Instance prompt: 'a photo of a vy water bottle'
#   Class prompt:    'a photo of a water bottle'
#   Prior preservation: False (λ=0.0)
#   Learning rate:   5e-06
#   Max steps:       800
#   Train text encoder: False
#   Train identifier embedding: True
#   UNet train mode: cross_attention
#   8-bit Adam: True
#   Device: cuda, compute dtype: torch.float16
# ...
#
# [1/5] Loading pretrained model components...
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
# run the inference script with the path to your saved model and a prompt
# replace <model_name> with the model name you provided in the last cell
# the model was saved in the 'final' subdirectory within your output directory <output_dis>
# !python /content/cs4782-final-project/code/inference.py \
    --model_path /content/cs4782-final-project/<model_name>/final \
    --identifier "<identifier>" \
    --class_noun "a photo of a <subject class>" \
    --prompt "a photo of a <identifier> <subject class> on a beach" \
    --output_dir /content/cs4782-final-project/data/results/<output_dir>
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading model from /content/cs4782-final-project/cs4782-final-project/model-water-bottle-prev-2-500-steps/checkpoint-800...
# Loading pipeline components...:  20% 1/5 [00:03<00:15,  3.84s/it]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 8848.74it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 4108.04it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 3223.91it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...

# %% [markdown]
# The generated images will be saved in the `/content/cs4782-final-project/results` directory.

# %%
# evaluate performance
# !python /content/cs4782-final-project/code/performance.py \
  --real_dir /content/cs4782-final-project/data/<subject_images_dir> \
  --gen_dir /content/cs4782-final-project/results/<output_dir> \
  --prompt "a photo of a <identifier> <class noun> in <new context>" \
  --output /content/cs4782-final-project/results/<output_dir>
