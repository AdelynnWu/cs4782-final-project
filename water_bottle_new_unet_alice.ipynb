# %% [markdown]
# <a href="https://colab.research.google.com/github/AdelynnWu/cs4782-final-project/blob/main/water_bottle_new_unet_alice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision diffusers transformers accelerate Pillow tqdm -q

# %%
# Setup
import os
from getpass import getpass

if not os.path.exists("cs4782-final-project"):
    token = getpass('GitHub token: ')
    # !git clone https://AdelynnWu:{token}@github.com/AdelynnWu/cs4782-final-project.git

# %cd cs4782-final-project
# Out:
# GitHub token: ··········
# Cloning into 'cs4782-final-project'...
# remote: Enumerating objects: 655, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 655 (delta 15), reused 22 (delta 7), pack-reused 620 (from 1)
# Receiving objects: 100% (655/655), 383.03 MiB | 44.56 MiB/s, done.
# Resolving deltas: 100% (72/72), done.
# Updating files: 100% (519/519), done.
# /content/cs4782-final-project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install bitsandbytes -q
# !python -c "import bitsandbytes as bnb; print('bitsandbytes ok')"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 17.4 MB/s eta 0:00:00
# bitsandbytes ok

# %%
# !python /content/cs4782-final-project/code/train.py \
  --subject_dir /content/cs4782-final-project/data/water-bottle-subject-img\
  --class_dir /content/cs4782-final-project/data/class_images_waterbottle\
  --class_noun "water bottle" \
  --identifier "vy" \
  --output_dir /content/cs4782-final-project/model-water-bottle-prev-75-500-steps\
  --steps 500 \
  --lr 5e-6 \
  --unet_train_mode cross_attention\
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# DreamBooth Training
# ...
#   Instance prompt: 'a photo of a vy water bottle'
#   Class prompt:    'a photo of a water bottle'
#   Prior preservation: True (λ=0.75)
#   Learning rate:   5e-06
#   Max steps:       500
#   Train text encoder: False
#   Train identifier embedding: True
#   UNet train mode: cross_attention
#   8-bit Adam: True
#   Device: cuda, compute dtype: torch.float16
# ...
#
# [1/5] Loading pretrained model components...
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 5.05MB/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
# To test the trained model, run the inference script with the path to your saved model and a prompt.
# The model was saved in the 'final' subdirectory within your output directory.
# !python /content/cs4782-final-project/code/inference.py \
    --model_path /content/cs4782-final-project/model-water-bottle-prev-50-500-steps/final\
    --identifier "vy" \
    --class_noun "a photo of a water bottle" \
    --prompt "a photo of a vy water bottle on a beach" \
    --output_dir /content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading model from /content/cs4782-final-project/model-water-bottle-prev-50-500-steps/final...
# Loading pipeline components...:  40% 2/5 [00:00<00:01,  2.75it/s]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 8738.13it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 3872.86it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 3192.01it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...

# %%
# !python /content/cs4782-final-project/code/performance.py --real-dir='/content/cs4782-final-project/data/water-bottle-subject-img --gen-dir /content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps --prompt "a photo of a vy water bottle on a beach" --output /content/cs4782-final-project/performance.txt
# Out:
# usage: performance.py [-h] --real_dir REAL_DIR --gen_dir GEN_DIR --prompt
#                       PROMPT [--output OUTPUT]
# performance.py: error: the following arguments are required: --real_dir, --gen_dir

# %%
# !zip -r output-prev-50-500.zip /content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps
# Out:
#   adding: content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps/ (stored 0%)
#   adding: content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps/a_photo_of_a_vy_water_bottle_on_a_beach_02.png (deflated 0%)
#   adding: content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps/a_photo_of_a_vy_water_bottle_on_a_beach_01.png (deflated 0%)
#   adding: content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps/a_photo_of_a_vy_water_bottle_on_a_beach_03.png (deflated 0%)
#   adding: content/cs4782-final-project/inference_output_water-bottle-prev-50-500-steps/a_photo_of_a_vy_water_bottle_on_a_beach_00.png (deflated 0%)

# %%
# !zip -r model-water-bottle-prev-50-500.zip /content/cs4782-final-project/model-water-bottle-prev-50-500-steps/final
# Out:
# 	zip warning: name not matched: /content/cs4782-final-project/model-water-bottle-prev-50-500-steps/final
#
# zip error: Nothing to do! (try: zip -r model-water-bottle-prev-50-500.zip . -i /content/cs4782-final-project/model-water-bottle-prev-50-500-steps/final)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

image_dir = '/content/cs4782-final-project/inference_output'
image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])

if image_files:
    print(f"Displaying generated images from {image_dir}:")
    for img_file in image_files:
        img_path = os.path.join(image_dir, img_file)
        img = mpimg.imread(img_path)
        plt.imshow(img)
        plt.title(img_file)
        plt.axis('off') # Hide axes ticks
        plt.show()
else:
    print(f"No images found in {image_dir}")

# %%
# %cd /content/cs4782-final-project/
# Out:
# /content/cs4782-final-project

# %%
import shutil

shutil.make_archive('output_0', 'zip', '/content/cs4782-final-project/output')

# %%
from google.colab import files
files.download('my_folder.zip')
